# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/TrafficLightDetection/
# Out:
# /content/drive/MyDrive/TrafficLightDetection

# %%
ls
# Out:
# dataset/           main.py              model_scripted.pth      train.py
# images/            mini_train_dataset/  __pycache__/            utils.py
# learning_plot.png  model.py             TrafficLightDataset.py

# %%
# !python train.py
# Out:
# cuda
# ./dataset/train/annotations.xml
# The number of images:  100
# ----------------------------------
# image_id:  0
# image_name:  Snapshot.JPG
# original_image_width:  1920.0
# original_image_height:  1080.0
# labels:  tensor([2, 3, 2, 3, 2, 3, 2, 2])
# bboxes:  tensor([[1178.8000,  604.2700, 1220.1000,  619.7200],
#         [1206.7700,  619.7700, 1220.5400,  634.0200],
#         [1062.0200,  683.7500, 1080.5200,  691.2500],
#         [1073.4000,  691.2000, 1081.4200,  698.5500],
#         [ 889.6300,  676.6800,  907.7300,  683.9800],
#         [ 901.2300,  683.8800,  908.7300,  691.8800],
#         [ 928.7200,  713.4500,  938.8000,  717.7700],
#         [1002.6400,  717.4100, 1012.8400,  722.9300]])
# ----------------------------------
# image_id:  1
# image_name:  Snapshot_1.JPG
# original_image_width:  1920.0
# original_image_height:  1080.0
# labels:  tensor([2, 3, 2, 3, 2, 2, 3])
# bboxes:  tensor([[1224.2000,  575.5400, 1277.5900,  592.7300],
# ...
